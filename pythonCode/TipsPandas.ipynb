# %%
import pandas as pd
import numpy as np

# %%
#imprort de données
file_path ="20220424_tipsPandas/2_Prepared_Data/train.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#dimension du jeu de donnée
df.shape
# Out:
# (1460, 81)

# %%
#travailler aves les 100 première lignes du jeu de données
df_100 = pd.read_csv(file_path, nrows=100)

# %%
df_100.shape
# Out:
# (100, 81)

# %%
#afficher l'intégralité des 81 colonnes.
pd.set_option('max_columns', 1000)
df_100.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#import du module pandas_profiling
import pandas_profiling

# %%
#visualisation
profile = df_100.profile_report(title="Pandas Profiling Report")
profile.to_file(output_file="output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#types des colonnes
df_100.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#insertion d'une colonne à une position données
colonne_insert = df_100['MSSubClass']*df_100['LotArea']
df_100.insert(3, 'colonne_calcul', colonne_insert) # inserts at third column

# %%
df_100.head()
# Out:
#    Id  MSSubClass MSZoning  colonne_calcul  LotFrontage  LotArea Street Alley  \
# 0   1          60       RL          507000         65.0     8450   Pave   NaN
# 1   2          20       RL          192000         80.0     9600   Pave   NaN
# 2   3          60       RL          675000         68.0    11250   Pave   NaN
# 3   4          70       RL          668500         60.0     9550   Pave   NaN
# 4   5          60       RL          855600         84.0    14260   Pave   NaN
#
#   LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0      Reg         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1      Reg         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2      IR1         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3      IR1         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4      IR1         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
# ...

# %%
#Selection de données en fonction du type

# %%
#selection de colonne numeric
df_100.select_dtypes(include ='number')
# Out:
#      Id  MSSubClass  colonne_calcul  LotFrontage  LotArea  OverallQual  \
# 0     1          60          507000         65.0     8450            7
# 1     2          20          192000         80.0     9600            6
# 2     3          60          675000         68.0    11250            7
# 3     4          70          668500         60.0     9550            7
# 4     5          60          855600         84.0    14260            8
# ..  ...         ...             ...          ...      ...          ...
# 95   96          60          585900          NaN     9765            6
# 96   97          20          205280         78.0    10264            7
# 97   98          20          218420         73.0    10921            4
# 98   99          30          318750         85.0    10625            5
# 99  100          20          186400         77.0     9320            4
#
#     OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# ...

# %%
#liste des colonnes categorielle
df_100.select_dtypes(include ='number').columns
# Out:
# Index(['Id', 'MSSubClass', 'colonne_calcul', 'LotFrontage', 'LotArea',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'PoolQC', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
#selection des colonnes cayegoriel
df_100.select_dtypes(include ='object')
# Out:
#    MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1        RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2        RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3        RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4        RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ..      ...    ...   ...      ...         ...       ...       ...       ...
# 95       RL   Pave   NaN      IR2         Lvl    AllPub    Corner       Gtl
# 96       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 97       RL   Pave   NaN      Reg         HLS    AllPub    Inside       Gtl
# 98       RL   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 99       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
#liste des colonnes categorielle
df_100.select_dtypes(include ='object').columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'Fence', 'MiscFeature', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
#Lecture fichier excel (choix des clonnes à considérer lors du chargement)
pd.read_excel("../2_Prepared_Data/P12-Bank-Customers-Demo.xlsx", usecols = ['Customer ID', 'Gender', 'Balance'])
# Out:
#     Customer ID  Gender      Balance
# 0   100000007.0  Female   $42,879.84
# 1   200000008.0  Female   $36,680.17
# 2   300000009.0  Female   $74,284.35
# 3   100000010.0    Male   $10,912.45
# 4   100000011.0    Male   $39,667.83
# 5   100000012.0    Male   $32,281.62
# 6   100000013.0    Male   $40,781.63
# 7   200000014.0    Male   $48,791.46
# 8   300000015.0  Female    $2,846.03
# 9   100000016.0    Male    $2,116.85
# 10  200000017.0  Female   $10,356.31
# 11  200000018.0  Female    $3,801.69
# 12  100000019.0    Male   $65,534.69
# 13  100000020.0  Female   $11,462.64
# 14  100000001.0    Male  $113,810.15
# 15  400000002.0  Female   $36,919.73
# 16  100000003.0    Male  $101,536.83
# 17  300000004.0    Male    $1,421.52
# 18  100000005.0  Female   $35,639.79
# 19  300000006.0  Female  $122,443.77
